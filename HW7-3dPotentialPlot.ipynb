# %% [markdown]
# # Plotting in 3D
#
# From time to time, it will be useful to visualize a function of two variables (a surface of some sort). In our case, solving Laplace's equation in 2D will yield a solution for the potential that (in principle) depends on both spatial variables. In this problem, you will learn how to plot functions of the type $V(x,y)$ using the ```mplot3d``` library.
#
# We will remind ourselves of ```meshgrid``` in the process, which gives us a 2D grid of points with which we can use to calculate our function $V(x,y)$.
#
# In addition, you will need to develop a looped calculation (over $n$) to determine the approximate solution for $V(x,y)$ as it is was to be the infinite series:
#
# $$V(x,y) = \sum_{n=1,3,5,\dots}^{\infty} \dfrac{4 V_0}{\pi n} \sin \left(\dfrac{n\pi x}{a}\right)e^{-\dfrac{n\pi y}{a}}$$
#
# The next section illustrates how to plot a function of two variables. You will need to understand the second calculation cell well to solve this problem.
#
# ### [Skip to problem to solve](./HW5-3dPotentialPlot.ipynb#Problems-to-solve)

# %% [markdown]
# ## Importing the 3D plot library
#
# All we have to do is import ```Axes3D``` from the ```mplot3d``` in addition to the libraries that we typically important for clacualtions and plotting. Importing ```Axes3D``` gives us access to ```plot_surface```, which we will use to plot the function $V(x,y)$ as a surface over the $x-y$ plane.

# %%
from mpl_toolkits.mplot3d import Axes3D  ## Provides access to 3D Plotting functions
import matplotlib.pyplot as plt
import numpy as np
import math
# %matplotlib inline

# %% [markdown]
# ## Plotting in 3D
#
# Let's plot the function:
# $$V(x,y) = V_0\left(\left(\frac{x}{a}\right)^2+\left(\frac{y}{a}\right)^2\right)$$
# where $V_0 = 10 V$ and $a = 1 m$. Notice this equation **does not** satisfy Laplace's equation.
#
# To make this plot, we have to create a figure and 3D Axes. That's what the first two lines do. You need these each time you create a new 3D figure. We then set the constants in the equation.
#
# The next three lines create the mesh of 2D points on which we will calculate and graph the surface. We use ```linespace``` to create a list of 100 eqaully-spaced numbers from 0 to 1. ```meshgrid``` then creates the pairs of points on which we will plot the surface.
#
# The next line calculates the function $V(x,y)$. Notice that it uses the variables returned by ```meshgrid```, that is ```X``` and ```Y``` not ```x``` and ```y```.
#
# Finally, we plot the function using ```plot_surface```. The extra parameters just make things look a bit nice.

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

a = 1
V0 = 10

x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
X,Y = np.meshgrid(x,y)

V = V0*((X/a)**2+(Y/a)**2)

ax.plot_surface(X, Y, V, rstride=4, cstride=4, color='y')

# %% [markdown]
# ## Problems to Solve
#
# You will need to create 3 plots for the potential we found in class:
#
# $$V(x,y) = \sum_{n=1,3,5,\dots}^{\infty} \dfrac{4 V_0}{\pi n} \sin \left(\dfrac{n\pi x}{a}\right)e^{-\dfrac{n\pi y}{a}}$$
#
# with $V_0=10V$ and $a=1m$.
#
# Each plot you need to make is listed below:
#
# 1. Plot the approximate solutionfor just the first term in the sum (i.e., only for $n = 1$).
# 2. Plot the approximate solution in 3D space for the first 5 terms.
# 3. Plot the approximate solution for the first 100 terms. If you didn't do it for Part 2, you will have to figure out how to automatically compute each term to construct your plot instead of copying-and-pasting 100 times!
#
# Hint: You can copy-and-paste most of the code from the previous calculation cell to handle the setup.

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

a = 1
V0 = 10

x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
X,Y = np.meshgrid(x,y)

##The thing I did 
V = 4*V0/np.pi * np.sin(np.pi*X/a) * np.e**(-1*np.pi*Y/a)
ax.plot_surface(X, Y, V, rstride=4, cstride=4, color='y')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

a = 1
V0 = 10

x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
X,Y = np.meshgrid(x,y)

V = 0
N = 5
for k in range(1,N-1,2): 
    V += 4*V0/(np.pi*k) * np.sin(k*np.pi*X/a) * np.e**(-k*np.pi*Y/a)

ax.plot_surface(X, Y, V, rstride=4, cstride=4, color='y')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

a = 1
V0 = 10

x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
X,Y = np.meshgrid(x,y)


##From question 3
V = 0
N = 50
for k in range(1,N-1,2): 
    V += 4*V0/(np.pi*k) * np.sin(k*np.pi*X/a) * np.e**(-k*np.pi*Y/a)
plt.title("50 terms of V")
ax.plot_surface(X, Y, V, rstride=4, cstride=4, color='y')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

a = 1
V0 = 10

x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
X,Y = np.meshgrid(x,y)

V = 0
N = 100
for k in range(1,N-1,2): 
    V += 4*V0/(np.pi*k) * np.sin(k*np.pi*X/a) * np.e**(-k*np.pi*Y/a)
plt.title("100 terms of V")
ax.plot_surface(X, Y, V, rstride=4, cstride=4, color='y')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

a = 1
V0 = 10

x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
X,Y = np.meshgrid(x,y)

V = 0
N = 100
for k in range(1,N-1,2): 
    V += 4*V0/(np.pi*k) * np.sin(k*np.pi*X/a) * np.e**(-k*np.pi*Y/a)
plt.title("1000 terms of V")
ax.plot_surface(X, Y, V, rstride=4, cstride=4, color='y')

# %%
##V ends up being close to constant at around 100 terms
